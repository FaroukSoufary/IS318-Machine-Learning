# %% [markdown]
# # IS318 - Machine Learning
#
# ## TP1 - Linear regression
#
# The goal of this TP is to experiment with linear regression and polynomial linear regression.
#
# First, we will work **without** the use of external libraries (such as `scikit-learn`).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Dataset

# %%
# Let us generate data points from a relatively complicated function
N = 100
alpha, sigma = 2., 3.
X = np.linspace(-3, 3, num=N)
y = X + (alpha * np.sin((2. * np.pi * X) / sigma) * np.exp(-(X ** 2) / (sigma ** 2)))
# Add some random noise
rng = np.random.default_rng(42)
y_noisy = y + rng.standard_normal(N) * 2.
# Show the data points
plt.plot(X, y_noisy, 'o')
plt.plot(X, y)
plt.tight_layout()

# %% [markdown]
# **(Question)** Shuffle and split the dataset into training (75%) and validation (25%) sets. Store the results into variables `X_train`, `y_train`, `X_valid`, `y_valid`.
#
# *Hint:* you can use `rng.permutation` to generate a random permutation of the points.

# %%
# YOUR CODE HERE

rng = np.random.default_rng()
indexes = [ i for i in range(len(X)) ]
permuted_indexes = rng.permutation(indexes)

X_p = X[permuted_indexes]
y_p = y_noisy[permuted_indexes]

n = len(X_p)
i_75 = int(0.75*n)


X_train = X_p[:i_75]
y_train = y_p[:i_75]

X_valid = X_p[i_75:]
y_valid = y_p[i_75:]

# %%
assert X_train.shape == (75,)
assert y_train.shape == (75,)
assert X_valid.shape == (25,)
assert y_valid.shape == (25,)
assert np.any(X_valid != X[75:]) # points should be shuffled

# %% [markdown]
# ### 2. Linear regression in 1D
#
# Recall the 1D linear regression model, where we search for parameters $w_0, w_1$ that will satisfy $y_i = w_0 + w_1 x_i$ (for all $i$ in the training set).
#
# To simplify calculations, we usually set $\textbf{w} = [w_0, w_1]^T$ and $\textbf{x}_i = [1, x_i]^T$.
#
# Then we have $y_i = \textbf{w}^T \textbf{x}_i $.

# %% [markdown]
# **(Question)** Add a column with ones to the points in `X_train` and `X_valid`. Store the result in new variables `X_train_ones` and `X_valid_ones`:

# %%
# YOUR CODE HERE

X_train_ones = np.column_stack((np.ones(len(X_train)),X_train))
X_valid_ones = np.column_stack((np.ones(len(X_valid)),X_valid))

# %% [markdown]
# **(Question)** Use normal equations to find the parameters that minimize the mean squared error on the training set.

# %%
# YOUR CODE HERE
XTX = np.dot(np.transpose(X_train_ones), X_train_ones)
XTX_1 = np.linalg.inv(XTX)
XTX_1XT = XTX_1 @ np.transpose(X_train_ones)
w = np.dot(XTX_1XT, y_train)

print(w)
# Out:
# [-0.15633893  0.75385021]

# %%
assert w.shape == (2,)

# %% [markdown]
# **(Question)** Plot the fitted line on top of the data points. Explain the result. (complete the code and answer in the cell below)

# %%
# YOUR CODE HERE
fitted_x = np.linspace(-3,3,N)
fitted_y = [w[0]+w[1]*x for x in fitted_x]

plt.plot(fitted_x, fitted_y, c='red')
plt.scatter(X_train, y_train)
plt.show()

# %% [markdown]
# (Answer) : The model is represented by the red line on the graph. The red line is defined by the parameter vector W that was found by the process of the cost minimization. That means that the line is the closest linear model to the data and it can be visually noticed that the line goes through the middle of the cloud.

# %% [markdown]
# **(Question)** Plot the loss function landscape. What can you conclude from this visualization? (complete the code and answer in the cell below)
#
# *Hint: the loss landscape can be represented by a 2D map (for example of size 100x100) where in each coordinate $(w_0, w_1)$ the value is mean squared error for these parameters. You can use `plt.contourf` to visualize the result.*

# %%
# YOUR CODE HERE

def Cost_for_contourf(w0, w1, X, y):
    W = np.row_stack((w0, w1))
    X = np.column_stack((np.ones(len(X)),X))
    y_hat = np.dot(X, W)
    y_hat_columns = [y_hat[:,i] for i in range(y_hat.shape[1])]
    cost = [np.linalg.norm(y_hat_i-y)/N for y_hat_i in y_hat_columns]
    return cost

w0 = np.linspace(-2, 5, 100)
w1 = np.linspace(-2, 5, 100)

W0, W1 = np.meshgrid(w0, w1)

initial_shape = W0.shape


W0 = W0.ravel()
W1 = W1.ravel()
Z = np.array(Cost_for_contourf(W0, W1, X_train, y_train))

W0 = W0.reshape(initial_shape)
W1 = W1.reshape(initial_shape)
Z = Z.reshape(initial_shape)


plt.contourf(W0, W1, Z, 20, cmap='plasma')
plt.plot([w[0]],[w[1]],'o')
plt.colorbar()

# %% [markdown]
# (Answer) : According to the visualization above, we conclude that the vector W that we found before is the best parameter vector because it minimizes the cost function since it is located in the minimum cost area on the landscape graph.

# %% [markdown]
# ### 3. Polynomial linear regression
#
# We move on the polynomial linear regression model with degree $D$, where the relationship between $y_i$ and $x_i$ is
# $ y_i = w_0 + w_1x_i + w_2x_i^2 + \ldots + w_D x_i^D $
#
# With $\textbf{w} = [w_0, \ldots, w_D]^T$ and $\textbf{x}_i = [1, x_i, x_i^2, \ldots, x_i^D]^T$, we have $y_i = \textbf{w}^T \textbf{x}_i $.
#
# $D \geq 1$ is an hyperparameter of the model.

# %% [markdown]
# **(Question)** Complete the following `PolynomialRegression` class

# %%
class PolynomialRegression():
    def __init__(self, D=1):
        assert D >=1
        self.D = D
        
    def fit(self, X, y):
        '''Apply polynomial linear regression to fit `X` to `y`.
        The result should be stored in an attribute `w`.'''
        # YOUR CODE HERE
        X_poly = self.make_poly(X)
        self.w = np.linalg.inv(X_poly.T @ X_poly) @ X_poly.T @ y
        
    def predict(self, X):
        '''Assuming the model has already been fit, return
        predicted `y` values for given `X`.'''
        # YOUR CODE HERE
        X_poly = self.make_poly(X)
        return X_poly @ self.w

    def make_poly(self, X):
        '''Augment a dataset of 1D points (vector of size N) to its
        data matrix in polynomial form, including the zero column 
        (matrix of size N x D+1). Return the data matrix.'''
        assert X.ndim == 1
        data_matrix = np.zeros((len(X),self.D+1))
        for i in range(len(X)):
            for j in range(self.D+1):
                data_matrix[i,j] = X[i]**j

        return data_matrix

# %% [markdown]
# **(Question)** Implement the mean squared error function to measure the quality of predictions.

# %%
def mean_squared_error(y_true, y_pred):
    '''Return the mean squared error between `y_true` and `y_pred`.'''
    assert y_true.shape == y_pred.shape
    # YOUR CODE HERE
    return np.sum((y_true - y_pred)**2) / len(y_true)

# %%
a, b = np.random.randn(10), np.random.randn(10)
assert mean_squared_error(a, b) >= 0.
assert mean_squared_error(a, a) == 0.

# %% [markdown]
# **(Question)** Apply the polynomial regression model with $D=5$. Compute and print the mean squared error for the training and validation sets.

# %%
# YOUR CODE HERE
model = PolynomialRegression(D=5)


model.fit(X_train, y_train)
y_pred_train = model.predict(X_train)
y_pred_val = model.predict(X_valid)

our_err_tr = mean_squared_error(y_train, y_pred_train)
our_err_val = mean_squared_error(y_valid, y_pred_val)


print("***** Training data ********")
print("mse : ", our_err_tr)
print("***** Valid data ********")
print("mse : ", our_err_val)
# Out:
# ***** Training data ********
# mse :  2.2776917791921782
# ***** Valid data ********
# mse :  3.1235978848750805

# %% [markdown]
# **(Question)** Plot the fitted polynomial curve on top of the data points. Explain the result. (complete the code and answer in the cell below)

# %%
# YOUR CODE HERE

def poly(x, w):
    sum = 0
    for i in range(len(w)):
        sum += w[i] * x**i
    return sum


plt.plot(X, y_noisy, 'o')

w = model.w

fitted_x = np.linspace(-3,3,100)
fitted_y = np.array([poly(x,w) for x in fitted_x])

plt.plot(fitted_x, fitted_y, label="fitted curve")
plt.plot(X, y, label="real curve")
plt.legend()

# %% [markdown]
# (Answer) : The parameter W that we found after training our model defines the best fitting polynomial function to our training dataset. The curve that we see on the graph represents the polynomial function that is defined by W. We notice that the curve is neither underfitting nor overfitting and thus, conclude that D=5 is not a bad hyperparameter but it can still be improved as there is still some important differences between the fitted curve and the real curve

# %% [markdown]
# **(Question)** Using the validation set, implement a simple model selection strategy to optimize hyperparameter $D$ and print this value. For this question, you should limit the search to $D \in [1, 15]$.
# To visualize potential underfitting and overfitting effects, plot the evolution of the error on the training and the validation sets for the different values of $D$.

# %%
# YOUR CODE HERE
D_vals = np.arange(1,16)

err_array = []

for D in D_vals:
    model = PolynomialRegression(D=D)

    model.fit(X_train, y_train)

    y_pred_train = model.predict(X_train)
    y_pred_val = model.predict(X_valid)

    err_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
    err_val = np.sqrt(mean_squared_error(y_valid, y_pred_val))
    
    err_array.append([err_tr, err_val])

err_array = np.array(err_array)
plt.errorbar(D_vals, err_array[:,0], color='black', label='Training set', fmt='o-')
plt.errorbar(D_vals, err_array[:,1], color='red', label='Validation set',fmt='o-')
plt.legend()
#To find the best value of D, we search the value that had the minimum cost value on the validation dataset
best_D = D_vals[np.where(err_array[:,1]==np.min(err_array[:,1]))[0][0]]
print("D* = " + str(best_D))
# Out:
# D* = 8

# %% [markdown]
# **(Question)** Plot the fitted polynomial curve of the best model on top of the data points. Comment the results.

# %%
# YOUR CODE HERE
plt.plot(X, y_noisy, 'o')
plt.plot(X, y, 'g', label='real curve')

best_model = PolynomialRegression(D=best_D)

best_model.fit(X_train, y_train)
w = best_model.w

fitted_x = np.linspace(-3,3,100)
fitted_y = np.array([poly(x,w) for x in fitted_x])

plt.plot(fitted_x, fitted_y, label='fitted curve')
plt.title("Data points and fitted curve D = " + str(best_D))
plt.legend()

# %% [markdown]
# (Answer) : According to the curves, we notice that for D=8 (might change), the curve is the closest possible to the real curve. We also made sure by visualizing the curve for the different values of D between 1 and 15. We conclude that our simple strategy for optimizing the value of D by minimizing the error on the validation dataset is working fine with our model.

# %% [markdown]
# ### 4. Regularized polynomial regression
#
# Now, we want to implement polynomial regression with *weight decay* regularization:
# $\hat{L}(\textbf{w}) = \frac{1}{N} \lVert \textbf{X} \textbf{w} - \textbf{y} \rVert^2 + \lambda \lVert\textbf{w}\rVert^2$
#
# Here, $\lambda \geq 0$ is another hyperparameter of our model.

# %% [markdown]
# **(Question)** Complete the following `RegularizedPolynomialRegression` class.

# %%
class RegularizedPolynomialRegression():
    def __init__(self, D=1, lmbda=1.):
        assert D >=1 and lmbda >= 0.
        self.D = D
        self.lmbda = lmbda
        
    def fit(self, X, y):
        '''Apply polynomial linear regression to fit `X` to `y`.
        The result should be stored in an attribute `w`.'''
        # YOUR CODE HERE
        X = self.make_poly(X)
        self.w = np.linalg.inv((self.lmbda * np.eye(self.D+1) + X.T @ X)) @ X.T @ y
        
        
        
    def predict(self, X):
        '''Assuming the model has already been fit, return
        predicted `y` values for given `X`.'''
        # YOUR CODE HERE
        X = self.make_poly(X)

        return np.dot(X, self.w)

    def make_poly(self, X):
        '''Augment a dataset of 1D points (vector of size N) to its
        data matrix in polynomial form, including the zero column 
        (matrix of size N x D+1). Return the data matrix.'''
        assert X.ndim == 1
        Poly_data = np.zeros((len(X), self.D+1))
        for i in range(len(X)):
            for j in range(self.D+1):
                Poly_data[i,j] = X[i]**j
        return Poly_data

# %% [markdown]
# **(Question)** Apply regularized linear regression and play around with hyperparameters $D$ and $\lambda$. Plot the result.

# %%
# YOUR CODE HERE

def computeLoss(y_hat, y):
    return np.linalg.norm(np.array(y_hat)-np.array(y))/len(y)

#We will try to explore all the possible coupls (D, lambda) for D in [1, 15] and lambda between 0 and 3
D = np.arange(1,16)
lambda_ = np.linspace(0, 3, 30)

D_vals, lambda_vals = np.meshgrid(D, lambda_)
 
initial_shape = D_vals.shape

D_vals = D_vals.ravel()
lambda_vals = lambda_vals.ravel()

L = []

#Here we train our regularized model with every possibility
for i in range(len(D_vals)):
    rpr_model = RegularizedPolynomialRegression(D=D_vals[i], lmbda=lambda_vals[i])
    rpr_model.fit(X_train, y_train)
    y_hat = rpr_model.predict(X_valid)
    loss = computeLoss(y_hat, y_valid)
    L.append(loss)

L = np.array(L)
    
# Here we search for the best couple (D, lambda) by searching for the minimum loss on the validation set

best_index = np.where(L == np.min(L))[0][0]
best_D = D_vals[best_index]
best_lambda = lambda_vals[best_index]

print("D* = " + str(best_D))
print("lambda* = " + str(best_lambda))

# Here we try to visualize the colormap :
    
D_vals = D_vals.reshape(initial_shape)
lambda_vals = lambda_vals.reshape(initial_shape)
L = L.reshape(initial_shape)

plt.contourf(D_ij, lambda_ij, Cost, 20, cmap='plasma')
plt.colorbar()
# Out:
# D* = 8
# lambda* = 0.0

# %%
#Here we plot the model we finally found (Which is the same as in part 3 (D=9, lambda=0))

rpr_model = RegularizedPolynomialRegression(D=best_D, lmbda=best_lambda)

fitted_x = np.linspace(-3,3,100)
fitted_y = np.array([poly(x,w) for x in fitted_x])

plt.plot(X, y, label='real curve', c='g')
plt.plot(fitted_x, fitted_y, label='fitted curve', c='red')
plt.scatter(X_train, y_train)
plt.title("Data points and fitted curve D = " + str(best_D) + " & lambda = " + str(best_lambda))
plt.legend()

# %% [markdown]
# ### 5. Comparison with `sklearn`

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge

# %% [markdown]
# **(Question)** Use the `sklearn` classes imported above to apply polynomial regression on our toy dataset. Compare the results with your implementation and comment.

# %%
# YOUR CODE HERE

polynom = PolynomialFeatures(degree=8)

X_train_poly = polynom.fit_transform(X_train.reshape(-1, 1))
X_val_poly = polynom.fit_transform(X_valid.reshape(-1, 1))

sk_model = LinearRegression()

sk_model.fit(X_train_poly, y_train)

y_pred_tr = sk_model.predict(X_train_poly)
y_pred_valid = sk_model.predict(X_val_poly)

# %%
# YOUR CODE HERE
print("Our model : ")
print("***** Training data ********")
print("mse : ", our_err_tr)
print("***** Valid data ********")
print("mse : ", our_err_val)
print("sklearn model : ")
print("***** Training data ********")
print("mse : ", mean_squared_error(y_train, y_pred_tr))
print("***** Valid data ********")
print("mse : ", mean_squared_error(y_valid, y_pred_valid))
# Out:
# Our model :
# ***** Training data ********
# mse :  2.2776917791921782
# ***** Valid data ********
# mse :  3.1235978848750805
# sklearn model :
# ***** Training data ********
# mse :  2.071856853145835
# ***** Valid data ********
# mse :  2.6968949888781513

# %%
plt.plot(X, y_noisy, 'o')
plt.plot(X, y, 'g', label='real curve')

sk_w = sk_model.coef_

w = best_model.w

fitted_x = np.linspace(-3,3,100)
sk_fitted_y = np.array([poly(x,sk_w) for x in fitted_x])
fitted_y = np.array([poly(x,w) for x in fitted_x])

plt.plot(fitted_x, fitted_y, color='b', label='our fitted curve')
plt.plot(fitted_x, sk_fitted_y,color='r', label='sklearn fitted curve')
plt.title("Data points and fitted curve (our model and sklearn)")
plt.legend()

# %%
degrees = np.arange(1,16)

err_array = []

for d in degrees:
        
    poly = PolynomialFeatures(degree=d)

    X_train_poly = poly.fit_transform(X_train.reshape(-1, 1))
    X_val_poly = poly.fit_transform(X_valid.reshape(-1, 1))

    sk_model = LinearRegression()

    sk_model.fit(X_train_poly, y_train)

    y_pred_tr = sk_model.predict(X_train_poly)
    y_pred_valid = sk_model.predict(X_val_poly)

    err_tr = np.sqrt(mean_squared_error(y_train, y_pred_tr))
    err_val = np.sqrt(mean_squared_error(y_valid, y_pred_valid))
    
    err_array.append([err_tr, err_val])

err_array = np.array(err_array)
plt.errorbar(degrees, err_array[:,0], color='black', label='Training set', fmt='o-')
plt.errorbar(degrees, err_array[:,1], color='red', label='Validation set',fmt='o-')
plt.legend()

# %% [markdown]
# We notice that our model has a very close mse value to the sklearn model in both, the training and validation set.
# Additionally, our curve and sklearn's curve are very similar and close to each other.
# Moreover, the error curves of sklearn's model look completely similar to those of our model.
# We conclude that our linear regression implementation was successful and we are glad about it !
